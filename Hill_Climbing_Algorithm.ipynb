# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='r', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    return x / y


print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

while True:
    
    choice = input("Enter choice(1/2/3/4): ")

    
    if choice in ('1', '2', '3', '4'):
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))

        if choice == '1':
            print(num1, "+", num2, "=", add(num1, num2))
        elif choice == '2':
            print(num1, "-", num2, "=", subtract(num1, num2))
        elif choice == '3':
            print(num1, "*", num2, "=", multiply(num1, num2))
        elif choice == '4':
            print(num1, "/", num2, "=", divide(num1, num2))
        break
    else:
        print("Invalid Input")
# Out:
# Select operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# Enter choice(1/2/3/4): 1
# Enter first number: 5
# Enter second number: 10
# 5.0 + 10.0 = 15.0

# %%
# !pip install kaggle

# %%
mkdir .kaggle
# Out:
# mkdir: cannot create directory ‘.kaggle’: File exists

# %%
import json
token = {"username":"singharyaman","key":"4e7494829233404cd25f0425a51752db"}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-460132dcf360> in <module>()
#       1 import json
#       2 token = {"username":"singharyaman","key":"4e7494829233404cd25f0425a51752db"}
# ----> 3 with open('/content/.kaggle/kaggle.json', 'w') as file:
#       4     json.dump(token, file)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/.kaggle/kaggle.json'

# %%
cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json

# %%
# !kaggle config set -n path -v{/content}
# Out:
# ...
# - path is now set to: {/content}

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                               title                                             size  lastUpdated          downloadCount
# ----------------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------
# gpreda/covid19-tweets                                             COVID19 Tweets                                    20MB  2020-08-13 11:12:23           1717
# christianlillelund/passenger-list-for-the-estonia-ferry-disaster  The Estonia Disaster Passenger List               14KB  2020-07-26 15:40:17            492
# futurecorporation/epitope-prediction                              COVID-19/SARS B-cell Epitope Prediction            1MB  2020-07-24 02:53:28            409
# Cornell-University/arxiv                                          arXiv Dataset                                      2GB  2020-05-06 23:18:35           1279
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
data = pd.read_csv("AI_Lab/Concrete.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-1825d99238c3> in <module>()
#       1 import pandas as pd
# ----> 2 data = pd.read_csv("AI_Lab/Concrete.csv")
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
|!pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-332100ed-3c62-4c62-8be2-daad46b7ab87" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-332100ed-3c62-4c62-8be2-daad46b7ab87">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
# !cp kaggle.json ~/.kaggle/
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d kushalvala/concrete
# Out:
# ...
#   0% 0.00/10.2k [00:00<?, ?B/s]
# 100% 10.2k/10.2k [00:00<00:00, 3.84MB/s]

# %%
from zipfile import ZipFile
file_name = "concrete.zip"

with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import pandas as pd
df = pd.read_csv('Concrete.csv')
df.head()
# Out:
#    cement   slag  flyash  water  ...  coarseaggregate  fineaggregate  age  csMPa
# 0   540.0    0.0     0.0  162.0  ...           1040.0          676.0   28  79.99
# 1   540.0    0.0     0.0  162.0  ...           1055.0          676.0   28  61.89
# 2   332.5  142.5     0.0  228.0  ...            932.0          594.0  270  40.27
# 3   332.5  142.5     0.0  228.0  ...            932.0          594.0  365  41.05
# 4   198.6  132.4     0.0  192.0  ...            978.4          825.5  360  44.30
#
# [5 rows x 9 columns]

# %%
import random 
import string 
 
def generate_random_solution(length=15):
  return [random.choice(string.printable) for _ in range(length)]

# %%
def evaluate(solution): 
    target = list("Hello, World!") 
    diff = 0
    for i in range(len(target)): 
        s = solution[i] 
        t = target[i] 
        diff += abs(ord(s) - ord(t)) 
    return diff

# %%
def mutate_solution(solution): 
    index = random.randint(0, len(solution) - 1) 
    solution[index] = random.choice(string.printable)

# %%
best = generate_random_solution() 
best_score = evaluate(best)

# %%
while True: 
    print('Best score so far', best_score, 'Solution', "".join(best)) 
 
    if best_score == 0: 
        break
 
    new_solution = list(best) 
    mutate_solution(new_solution) 
 
    score = evaluate(new_solution) 
    if evaluate(new_solution) < best_score: 
        best = new_solution 
        best_score = score
# Out:
# Best score so far 398 Solution 70eb:.!O:(~vu`x
# Best score so far 398 Solution 70eb:.!O:(~vu`x
# Best score so far 380 Solution 70eb:.!O::~vu`x
# Best score so far 380 Solution 70eb:.!O::~vu`x
# Best score so far 380 Solution 70eb:.!O::~vu`x
# Best score so far 380 Solution 70eb:.!O::~vu`x
# Best score so far 380 Solution 70eb:.!O::~vu`x
# Best score so far 380 Solution 70eb:.!O::~vu`x
# Best score so far 380 Solution 70eb:.!O::~vu`x
# Best score so far 380 Solution 70eb:.!O::~vu`x
# Best score so far 375 Solution 70eg:.!O::~vu`x
# Best score so far 375 Solution 70eg:.!O::~vu`x
# Best score so far 375 Solution 70eg:.!O::~vu`x
# Best score so far 375 Solution 70eg:.!O::~vu`x
# Best score so far 375 Solution 70eg:.!O::~vu`x
# Best score so far 375 Solution 70eg:.!O::~vu`x
# Best score so far 375 Solution 70eg:.!O::~vu`x
# Best score so far 375 Solution 70eg:.!O::~vu`x
# Best score so far 371 Solution 70ig:.!O::~vu`x
# Best score so far 371 Solution 70ig:.!O::~vu`x
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bf09d246-2b46-44f3-a5ee-d7053876a27a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf09d246-2b46-44f3-a5ee-d7053876a27a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving filee.txt to filee.txt

# %%
uploaded
# Out:
# {'filee.txt': b'Hello'}

# %%
from google.colab import files
files.download('filee.txt')

# %%
from google.colab import drive
drive.mount('drive')

# %%
df.to_csv('c2.csv')
# !cp Concrete.csv "drive/My Drive/AI_Lab/"
